# %% [markdown]
# Nama : Yesi Dwi Ningtias
# NIM : 24060122120027

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 29.6 MB/s eta 0:00:00
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="UJau4NUhoEeIxaKQBhOU")
project = rf.workspace("yolo-9bs1n").project("deteksi-jenis-sampah-t5crt")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 12.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 52.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 69.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Deteksi-Jenis-Sampah-2 in yolov8:: 100%|██████████| 300/300 [00:00<00:00, 6783.61it/s]
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="/content/Deteksi-Jenis-Sampah-2/data.yaml",
    epochs=30,
)
# Out:
# ...
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO("/content/best.pt")

model.predict(
    source="/content/Deteksi-Jenis-Sampah-2/test/images",
    conf=0.05,
    save=True
)
# Out:
# image 1/6 /content/Deteksi-Jenis-Sampah-2/test/images/20251209_144412_jpg.rf.23edb263b7209f6c4dfee152fc290218.jpg: 640x640 1 organik, 8.3ms
# image 2/6 /content/Deteksi-Jenis-Sampah-2/test/images/20251209_144741_jpg.rf.f76acd003b2c7273ee8394f2e8d9baa9.jpg: 640x640 1 organik, 7.2ms
# image 3/6 /content/Deteksi-Jenis-Sampah-2/test/images/20251221_115058_jpg.rf.62d4b5c1ec61b368795738b714712eda.jpg: 640x640 2 anorganiks, 7.2ms
# image 4/6 /content/Deteksi-Jenis-Sampah-2/test/images/20251221_115117_jpg.rf.5bb6caa973dbfa5603665c43cc4b4b24.jpg: 640x640 2 anorganiks, 7.2ms
# image 5/6 /content/Deteksi-Jenis-Sampah-2/test/images/20251221_115558_jpg.rf.5c61da70fc16851c2e264f013145d07c.jpg: 640x640 1 anorganik, 7.2ms
# image 6/6 /content/Deteksi-Jenis-Sampah-2/test/images/20251221_135353_jpg.rf.81fa8df684fca057ada08ae76093e129.jpg: 640x640 1 anorganik, 7.2ms
# Speed: 2.4ms preprocess, 7.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# ...

# %%
from ultralytics import YOLO

model = YOLO("/content/best.pt")

model.predict(
    source="/content/sampah2.mp4",
    conf=0.25,
    save=True
)

# %%
# !pip install ultralytics opencv-python

# %%
from ultralytics import YOLO
import cv2
import numpy as np
from google.colab import output
from base64 import b64decode
from google.colab.patches import cv2_imshow

model = YOLO("best.pt")

# %%
def take_photo():
    js = output.eval_js('''
        async function takePhoto() {
          const div = document.createElement('div');
          const video = document.createElement('video');
          video.style.display = 'block';
          const stream = await navigator.mediaDevices.getUserMedia({video: true});
          document.body.appendChild(div);
          div.appendChild(video);
          video.srcObject = stream;
          await video.play();

          await new Promise(resolve => setTimeout(resolve, 2000));

          const canvas = document.createElement('canvas');
          canvas.width = video.videoWidth;
          canvas.height = video.videoHeight;
          canvas.getContext('2d').drawImage(video, 0, 0);

          stream.getTracks()[0].stop();
          div.remove();

          return canvas.toDataURL('image/jpeg', 0.8);
        }
        takePhoto();
    ''')
    return js

# %%
img_data = take_photo()

img_bytes = b64decode(img_data.split(',')[1])
img = cv2.imdecode(np.frombuffer(img_bytes, np.uint8), cv2.IMREAD_COLOR)

results = model(img, conf=0.25)
annotated = results[0].plot()

cv2_imshow(annotated)
# Out:
# 0: 480x640 1 anorganik, 6.8ms
# Speed: 2.0ms preprocess, 6.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# <PIL.Image.Image image mode=RGB size=640x480>
